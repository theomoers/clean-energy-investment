# %% [markdown]
# # Merging of datasets and preliminary analysis

# %%
import os
import time
import re
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import censusdata
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor, as_completed

notebook_dir = Path.cwd()
project_root = notebook_dir.parent
os.chdir(project_root)

randomState = 18

# plt.switch_backend('pgf') # change to 'pgf' for LaTeX export # use inline for Jupyter Notebook
# %matplotlib inline 

plt.rcParams.update({ 
    "pgf.texsystem": "pdflatex",
    "font.family": "serif",
    "text.usetex": True,
    "pgf.rcfonts": False,
    "axes.titlesize": 16,
    "axes.labelsize": 16,
    "xtick.labelsize": 14,
    "ytick.labelsize": 14,
    "legend.fontsize": 12,
    "legend.title_fontsize": 12,
})

CB_color_cycle = [
    '#56B4E9', '#008000', '#CC79A7', 
    '#009E73', '#984ea3', '#999999', 
    '#e41a1c', '#dede00', '#D55E00']

# %%
manuf_meta = pd.read_csv('data/manufacturing_energy_and_industry_facility_metadata.csv', header=3)
socioecon = pd.read_csv('data/socioeconomics.csv', header=3)

# %%
subset = manuf_meta[[
    'Segment', 
    'Technology', 
    'Subcategory', 
    'Decarb_Sector', 
    'Project_Type', 
    'Estimated_Total_Facility_CAPEX', 
    'CD119_2024_Name', 
    'Announcement_Date',
    'State',
    'US Senator 1: Party',
    'US Senator 2: Party',
    'US Representative Party',
    'Latitude',
    'Longitude',
    ]]

# get year range from announcement date
subset['Announcement_Date'] = pd.to_datetime(subset['Announcement_Date'], errors='coerce')
subset['Announcement_Year'] = subset['Announcement_Date'].dt.year # for overall year 
subset['Announcement_Quarter'] = subset['Announcement_Date'].dt.quarter # for seasonality
years = subset['Announcement_Year'].unique()
years.sort() # for socioeconomic data
# Out:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# #### Getting additional weather data

# %%
START = "20200101" 
END   = "20201231"

PARAMS = ["ALLSKY_SFC_SW_DWN", # All Sky Surface Shortwave Downward Irradiance
            "WS2M", # Wind Speed at 2 Meters
            "WS2M_MAX", # Maximum Wind Speed at 2 Meters
            "WS50M", # Wind Speed at 50 Meters
            "T2M", # Air Temperature at 2 Meters
            "T2M_MAX", # Maximum Air Temperature at 2 Meters
            "T2M_MIN", # Minimum Air Temperature at 2 Meters
            "PRECTOTCORR"] # Total Precipitation

PAUSE_SEC = 1.0

def fetch_nasa_power(lat, lon, start=START, end=END, parameters=PARAMS):
    base_url = "https://power.larc.nasa.gov/api/temporal/daily/point"
    params_str = ",".join(parameters)
    url = (
        f"{base_url}"
        f"?start={start}&end={end}"
        f"&latitude={lat}&longitude={lon}"
        f"&parameters={params_str}"
        f"&community=RE&format=JSON"
    )
    try:
        resp = requests.get(url, timeout=30)
        resp.raise_for_status()
    except requests.HTTPError as e:
        try:
            print(f"API error for ({lat}, {lon}):",
                  resp.status_code, resp.json())
        except Exception:
            print(f"API error for ({lat}, {lon}):", resp.status_code, resp.text)
        raise     
    data = resp.json()["properties"]["parameter"]
    dates = list(data[parameters[0]].keys())
    df = pd.DataFrame(
        {p: list(data[p].values()) for p in parameters},
        index=pd.to_datetime(dates, format="%Y%m%d"),
    )
    return df

def process_location(lat, lon):
    try:
        df_daily = fetch_nasa_power(lat, lon)
        annual_means = df_daily.mean().to_dict()
    except Exception:
        annual_means = {p: pd.NA for p in PARAMS}
    time.sleep(PAUSE_SEC)
    return {"Latitude": lat, "Longitude": lon, **annual_means}

# %%
# this takes very long, can just import resulting csv below
coords = list(zip(subset["Latitude"], subset["Longitude"]))

results = []
with ThreadPoolExecutor(max_workers=5) as executor: # Max threas given by the NASA Power is 5
    futures = [executor.submit(process_location, lat, lon) 
               for lat, lon in coords]
    for f in tqdm(as_completed(futures),
                  total=len(futures),
                  desc="Fetching data"):
        results.append(f.result())

df_results = pd.DataFrame(results)
subset_with_weather = subset.merge(df_results, on=["Latitude", "Longitude"], how="left")
subset_with_weather.head()
subset = subset_with_weather

subset_with_weather.to_csv("/data/posteda/subset_with_weather.csv", index=False)
# Out:
# Fetching data:  26%|██▌       | 2216/8532 [33:50<1:18:27,  1.34it/s]
# API error for (333.56812, -112.704): 422 {'header': 'The POWER Daily API failed to complete your request; please review the errors below and the POWER Docs (https://power.larc.nasa.gov/docs/).', 'messages': ['Please provide a correct latitude value.']}
# Fetching data:  84%|████████▍ | 7165/8532 [1:49:37<22:50,  1.00s/it]
# API error for (33.98049, -188.1581): 422 {'header': 'The POWER Daily API failed to complete your request; please review the errors below and the POWER Docs (https://power.larc.nasa.gov/docs/).', 'messages': ['Please provide a correct longitude value.']}
# Fetching data:  92%|█████████▏| 7807/8532 [1:59:17<09:41,  1.25it/s]
# API error for (333.56812, -112.704): 422 {'header': 'The POWER Daily API failed to complete your request; please review the errors below and the POWER Docs (https://power.larc.nasa.gov/docs/).', 'messages': ['Please provide a correct latitude value.']}
# Fetching data: 100%|██████████| 8532/8532 [2:10:11<00:00,  1.09it/s]

# %%
subset = pd.read_csv('data/posteda/subset_with_weather.csv')

# %%
# manualf fix for the row with lat=333.56812 and lon=-112.704 to correct values
subset.loc[(subset['Latitude'] > 333.0) & (subset['Latitude'] < 334.0) & (subset['Longitude'] < -112.0) & (subset['Longitude'] > -113.0), 'Latitude'] = 37.090240
subset.loc[(subset['Latitude'] > 333.0) & (subset['Latitude'] < 334.0) & (subset['Longitude'] < -112.0) & (subset['Longitude'] > -113.0), 'Latitude'] = -95.712891
subset = subset.drop_duplicates()

# %%
subset[PARAMS] = subset[PARAMS].apply(pd.to_numeric, errors='coerce')

max_iter = 5
iteration = 0

while iteration < max_iter:
    nan_rows = subset[subset[PARAMS].isna().all(axis=1)]
    if nan_rows.empty:
        print(f"All nans fixed after {iteration} iteration(s).")
        break
    print(f"Iteration {iteration + 1}: attempting to fix {len(nan_rows)} remaining row(s)…")

    coords = list(zip(nan_rows["Latitude"], nan_rows["Longitude"]))
    results = []

    with ThreadPoolExecutor(max_workers=5) as executor:
        futures = [executor.submit(process_location, lat, lon) for lat, lon in coords]
        for f in tqdm(as_completed(futures), total=len(futures), desc="Completing missing rows"):
            results.append(f.result())

    df_results = pd.DataFrame(results)

    extra_rows = nan_rows.merge(df_results, on=["Latitude", "Longitude"], how="left", suffixes=("", "_new"))

    for _, row in tqdm(extra_rows.iterrows(), total=extra_rows.shape[0], desc="Plugging values into original subset"):
        mask = (subset['Latitude'] == row['Latitude']) & (subset['Longitude'] == row['Longitude'])
        for p in PARAMS:
            subset.loc[mask, p] = row[f"{p}_new"]

    iteration += 1
else:
    remaining = subset[subset[PARAMS].isna().all(axis=1)]
    print(f"Reached max_iter={max_iter} with {len(remaining)} row(s) still missing data.")
    print("Overwriting previous csv")

# rename weather columns
subset.rename(columns={
    "ALLSKY_SFC_SW_DWN": "solar_irradiance",
    "WS2M": "wind_speed_2m",
    "WS2M_MAX": "wind_speed_2m_max",
    "WS50M": "wind_speed_50m",
    "T2M": "air_temp_2m",
    "T2M_MAX": "air_temp_2m_max",
    "T2M_MIN": "air_temp_2m_min",
    "PRECTOTCORR": "precipitation",
}, inplace=True)

# make a list using nice names
SELECT = ['solar_irradiance', 
          'wind_speed_2m', 
          'wind_speed_2m_max', 
          'wind_speed_50m', 
          'air_temp_2m', 
          'air_temp_2m_max', 
          'air_temp_2m_min', 
          'precipitation']

subset.to_csv("data/posteda/subset_with_weatherV2.csv", index=False)

# subset = pd.read_csv('/Users/theomoers/Documents/Columbia SIPA/Classes/Spring/Applying ML/ml-final-project/data/posteda/subset_with_weather.csv', header=0)
# Out:
# Iteration 1: attempting to fix 3 remaining row(s)…
# Completing missing rows:   0%|          | 0/3 [00:00<?, ?it/s]
# API error for (33.98049, -188.1581): 422 {'header': 'The POWER Daily API failed to complete your request; please review the errors below and the POWER Docs (https://power.larc.nasa.gov/docs/).', 'messages': ['Please provide a correct longitude value.']}
# Completing missing rows: 100%|██████████| 3/3 [00:06<00:00,  2.11s/it]
# Plugging values into original subset: 100%|██████████| 5/5 [00:00<00:00, 814.46it/s]
# Iteration 2: attempting to fix 1 remaining row(s)…
# Completing missing rows:   0%|          | 0/1 [00:00<?, ?it/s]
# API error for (33.98049, -188.1581): 422 {'header': 'The POWER Daily API failed to complete your request; please review the errors below and the POWER Docs (https://power.larc.nasa.gov/docs/).', 'messages': ['Please provide a correct longitude value.']}
# Completing missing rows: 100%|██████████| 1/1 [00:01<00:00,  1.25s/it]
# Plugging values into original subset: 100%|██████████| 1/1 [00:00<00:00, 225.94it/s]
# Iteration 3: attempting to fix 1 remaining row(s)…
# Completing missing rows:   0%|          | 0/1 [00:00<?, ?it/s]
# API error for (33.98049, -188.1581): 422 {'header': 'The POWER Daily API failed to complete your request; please review the errors below and the POWER Docs (https://power.larc.nasa.gov/docs/).', 'messages': ['Please provide a correct longitude value.']}
# Completing missing rows: 100%|██████████| 1/1 [00:01<00:00,  1.85s/it]
# Plugging values into original subset: 100%|██████████| 1/1 [00:00<00:00, 331.02it/s]
# Iteration 4: attempting to fix 1 remaining row(s)…
# Completing missing rows:   0%|          | 0/1 [00:00<?, ?it/s]
# API error for (33.98049, -188.1581): 422 {'header': 'The POWER Daily API failed to complete your request; please review the errors below and the POWER Docs (https://power.larc.nasa.gov/docs/).', 'messages': ['Please provide a correct longitude value.']}
# Completing missing rows: 100%|██████████| 1/1 [00:01<00:00,  1.51s/it]
# Plugging values into original subset: 100%|██████████| 1/1 [00:00<00:00, 381.96it/s]
# Iteration 5: attempting to fix 1 remaining row(s)…
# Completing missing rows:   0%|          | 0/1 [00:00<?, ?it/s]
# API error for (33.98049, -188.1581): 422 {'header': 'The POWER Daily API failed to complete your request; please review the errors below and the POWER Docs (https://power.larc.nasa.gov/docs/).', 'messages': ['Please provide a correct longitude value.']}
# Completing missing rows: 100%|██████████| 1/1 [00:01<00:00,  1.73s/it]
# Plugging values into original subset: 100%|██████████| 1/1 [00:00<00:00, 746.32it/s]
# Reached max_iter=5 with 1 row(s) still missing data.
# Overwriting previous csv

# %%
mask = subset[SELECT].isna().any(axis=1)
subset = subset[~mask]
subset.reset_index(drop=True, inplace=True)

# %%
# histogram of CAPEX, Fig A.1
fig, ax = plt.subplots(1, 2, figsize=(15, 6), dpi=200)
sns.histplot(subset['Estimated_Total_Facility_CAPEX'], bins=50, kde=True, ax=ax[0], color=CB_color_cycle[0])
ax[0].set_xlabel('Estimated Total Facility CAPEX')
ax[0].set_ylabel('Frequency')
ax[0].set_title('(A)')
loging = np.log(subset['Estimated_Total_Facility_CAPEX'] + 1)
sns.histplot(loging, bins=50, kde=True, ax=ax[1], color=CB_color_cycle[1])
ax[1].set_xlabel('Log of Estimated Total Facility CAPEX')
ax[1].set_title('(B)')
plt.tight_layout()
plt.savefig('figures/Methods/histogram_CAPEX.png', dpi=200)
plt.show()

# %%
capex = (pd.to_numeric(subset['Estimated_Total_Facility_CAPEX'], errors='coerce').dropna())
skew_val = stats.skew(capex)
kurt_val = stats.kurtosis(capex)
print(f"Skew: {skew_val:.3f}, Kurtosis (excess): {kurt_val:.3f}")
# Out:
# Skew: 10.433, Kurtosis (excess): 166.828

# %%
# plot select weather variables as histograms (6 in total), Fig. A.2
def plot_histograms(df, columns, ncols=3):
    nrows = (len(columns) + ncols - 1) // ncols
    fig, axes = plt.subplots(nrows, ncols, figsize=(18, 9), dpi=150)
    axes = axes.flatten()

    for i, col in enumerate(columns):
        sns.histplot(df[col], bins=30, kde=True, ax=axes[i])
        axes[i].set_title(col)
        axes[i].set_xlabel('')

    for j in range(i + 1, len(axes)):
        fig.delaxes(axes[j])

    plt.tight_layout()
    plt.savefig('figures/Methods/weather_data_distribution.png', bbox_inches='tight')
    plt.show()
plot_histograms(subset, SELECT, ncols=4)

# %% [markdown]
# #### Getting additional socioeconomic data

# %%
years = subset['Announcement_Year'].unique()
years.sort() # for socioeconomic data

# %%
vars_acs = {
    'B19013_001E': 'med_household_income',
    'B23025_005E': 'unemployed',
    'B01003_001E': 'total_pop',
    'B19083_001E': 'gini',
    
}
years = years[:-1] # 2024 not yet available, will be extrapolated, see below
def download_year(year):
    df = censusdata.download(
        src='acs5',
        year=year,
        geo=censusdata.censusgeo([('congressional district', '*')]),
        var=list(vars_acs.keys())
    )
    df = (
        df
        .rename(columns=vars_acs)
        .reset_index()
        .rename(columns={'index': 'geography'})
    )
    df['year'] = year
    return df

max_workers = min(len(years), os.cpu_count() or 1)
with ThreadPoolExecutor(max_workers=max_workers) as executor:
    results = list(
        tqdm(
            executor.map(download_year, years),
            total=len(years),
            desc='Downloading ACS by year'
        )
    )
df_acs = pd.concat(results, ignore_index=True)
df_acs.to_csv('data/posteda/acs_data.csv', index=False)
# Out:
# Downloading ACS by year: 100%|██████████| 9/9 [00:01<00:00,  5.66it/s]

# %%
df_acs['geography_str'] = df_acs['geography'].astype(str)
df_acs = df_acs[df_acs['geography_str'].str.contains('Congressional District')]
df_acs = df_acs[~df_acs['geography_str'].str.contains('not defined')]
df_acs = df_acs[~df_acs['geography_str'].str.contains('at large')]
df_acs = df_acs[~df_acs['geography_str'].str.contains('at Large')]
df_acs.to_csv('data/posteda/acs_data.csv', index=False)

# %%
df_acs['geography'] = df_acs['geography'].astype(str)

state2abbr = dict(pd.read_csv(
    "https://raw.githubusercontent.com/jasonong/List-of-US-States/master/states.csv"
).values)

def extract_cd(geo_str):
    m_state = re.search(r'\),\s*([^:]+):', geo_str)
    state_name = m_state.group(1).strip() if m_state else None
    abbr = state2abbr.get(state_name, '??')
    m_cd = re.search(r'congressional district[:\s]*(\d+)', geo_str, re.IGNORECASE)
    cd = m_cd.group(1).zfill(2) if m_cd else '00'
    return f"{abbr}-{cd}"

df_acs['state_cd'] = df_acs['geography'].apply(extract_cd)

# %%
def forecast_by_state(df,
                      vars_to_forecast=None,
                      group_col='state_cd',
                      start_year=2020,
                      end_year=2023,
                      forecast_year=2024):
    if vars_to_forecast is None:
        vars_to_forecast = ['med_household_income', 'unemployed', 'total_pop', 'gini']

    predictions = []
    df = df.copy()
    df['year'] = df['year'].astype(int)

    for state, grp in df.groupby(group_col):
        sub = grp[(grp['year'] >= start_year) & (grp['year'] <= end_year)]
        if len(sub) < 2:
            print(f"Skipping {state!r}: only {len(sub)} years of data")
            continue

        years = sub['year'].values
        pred_row = {group_col: state, 'year': forecast_year}
        for var in vars_to_forecast:
            y = sub[var].values
            m, b = np.polyfit(years, y, 1) # fit simple linear trend
            pred_row[var] = m * forecast_year + b
        predictions.append(pred_row)

    pred_df = pd.DataFrame(predictions)
    df_extended = pd.concat([df, pred_df], ignore_index=True)
    return df_extended

df_extended = forecast_by_state(df_acs)
df_extended.to_csv('data/posteda/acs_with_2024.csv', index=False)
df_acs = df_extended

# %%
df_acs = pd.read_csv('data/posteda/acs_with_2024.csv', header=0)
# make mask with no nan values for CD119_2024_Name
mask = subset['CD119_2024_Name'].isna()
subset = subset[~mask]
subset.reset_index(drop=True, inplace=True)

# %%
# for each row in subset, get the CD119_2024_Name, and add the corresponding socioeconomic data from df_acs
no_data_rows = []
vars_to_forecast = ['med_household_income', 'unemployed', 'total_pop', 'gini']
for variable in vars_to_forecast:
    temp_list = []
    for i, row in subset.iterrows():
        cd_name = row['CD119_2024_Name']
        project_year = row['Announcement_Year']

        if pd.isna(cd_name):
            print(f"Row {i} has no CD119_2024_Name")
            continue
        variable_value = df_acs.loc[
            (df_acs['state_cd'] == cd_name) & (df_acs['year'] == project_year), variable]
        if variable_value.empty:
            print(f"Row {i} has no socioeconomic data for {variable}")
            variable_value = pd.Series([np.nan])
            no_data_rows.append(i)
        else:
            variable_value = variable_value.iloc[0]
        temp_list.append(variable_value)
    print(f"Done: {variable}")
    subset[variable] = temp_list

# drop duplicates in no_data_rows and remove
no_data_rows = list(set(no_data_rows))
if no_data_rows:
    print(f"Removing {len(no_data_rows)} rows with no socioeconomic data")
    subset = subset.drop(index=no_data_rows)
    subset.reset_index(drop=True, inplace=True)

missing_rows = subset[subset[vars_to_forecast].isna().any(axis=1)]
if not missing_rows.empty:
    print(f"Missing socioeconomic data for {len(missing_rows)} rows. Removing them.")
    # create mask with no nan values for socioeconomic data
    mask = subset[vars_to_forecast].isna().any(axis=1)
    subset = subset[~mask]
    subset.reset_index(drop=True, inplace=True)
# Out:
# Row 123 has no socioeconomic data for med_household_income
# Row 177 has no socioeconomic data for med_household_income
# Row 376 has no socioeconomic data for med_household_income
# Row 423 has no socioeconomic data for med_household_income
# Row 429 has no socioeconomic data for med_household_income
# Row 432 has no socioeconomic data for med_household_income
# Row 434 has no socioeconomic data for med_household_income
# Row 445 has no socioeconomic data for med_household_income
# Row 463 has no socioeconomic data for med_household_income
# Row 464 has no socioeconomic data for med_household_income
# Row 486 has no socioeconomic data for med_household_income
# Row 490 has no socioeconomic data for med_household_income
# Row 543 has no socioeconomic data for med_household_income
# Row 546 has no socioeconomic data for med_household_income
# Row 552 has no socioeconomic data for med_household_income
# Row 557 has no socioeconomic data for med_household_income
# Row 563 has no socioeconomic data for med_household_income
# Row 567 has no socioeconomic data for med_household_income
# Row 580 has no socioeconomic data for med_household_income
# Row 581 has no socioeconomic data for med_household_income
# Row 582 has no socioeconomic data for med_household_income
# Row 583 has no socioeconomic data for med_household_income
# Row 584 has no socioeconomic data for med_household_income
# Row 592 has no socioeconomic data for med_household_income
# Row 593 has no socioeconomic data for med_household_income
# Row 595 has no socioeconomic data for med_household_income
# Row 600 has no socioeconomic data for med_household_income
# Row 606 has no socioeconomic data for med_household_income
# Row 609 has no socioeconomic data for med_household_income
# Row 619 has no socioeconomic data for med_household_income
# Row 625 has no socioeconomic data for med_household_income
# Row 633 has no socioeconomic data for med_household_income
# Row 639 has no socioeconomic data for med_household_income
# Row 641 has no socioeconomic data for med_household_income
# Row 675 has no socioeconomic data for med_household_income
# Row 676 has no socioeconomic data for med_household_income
# Row 708 has no socioeconomic data for med_household_income
# Row 760 has no socioeconomic data for med_household_income
# Row 789 has no socioeconomic data for med_household_income
# Row 799 has no socioeconomic data for med_household_income
# Row 809 has no socioeconomic data for med_household_income
# Row 825 has no socioeconomic data for med_household_income
# Row 826 has no socioeconomic data for med_household_income
# Row 827 has no socioeconomic data for med_household_income
# Row 828 has no socioeconomic data for med_household_income
# Row 829 has no socioeconomic data for med_household_income
# Row 830 has no socioeconomic data for med_household_income
# Row 833 has no socioeconomic data for med_household_income
# Row 851 has no socioeconomic data for med_household_income
# Row 852 has no socioeconomic data for med_household_income
# Row 853 has no socioeconomic data for med_household_income
# Row 854 has no socioeconomic data for med_household_income
# Row 855 has no socioeconomic data for med_household_income
# Row 987 has no socioeconomic data for med_household_income
# Row 990 has no socioeconomic data for med_household_income
# Row 991 has no socioeconomic data for med_household_income
# Row 1031 has no socioeconomic data for med_household_income
# Row 1040 has no socioeconomic data for med_household_income
# Row 1060 has no socioeconomic data for med_household_income
# Row 1098 has no socioeconomic data for med_household_income
# Row 1189 has no socioeconomic data for med_household_income
# Row 1311 has no socioeconomic data for med_household_income
# Row 1459 has no socioeconomic data for med_household_income
# Row 1555 has no socioeconomic data for med_household_income
# Row 1605 has no socioeconomic data for med_household_income
# Row 1620 has no socioeconomic data for med_household_income
# Row 1621 has no socioeconomic data for med_household_income
# Row 2008 has no socioeconomic data for med_household_income
# Row 2051 has no socioeconomic data for med_household_income
# Row 2098 has no socioeconomic data for med_household_income
# Row 2099 has no socioeconomic data for med_household_income
# Row 2100 has no socioeconomic data for med_household_income
# Row 2101 has no socioeconomic data for med_household_income
# Row 2206 has no socioeconomic data for med_household_income
# Row 2234 has no socioeconomic data for med_household_income
# Row 2242 has no socioeconomic data for med_household_income
# Row 2246 has no socioeconomic data for med_household_income
# Row 2247 has no socioeconomic data for med_household_income
# Row 2306 has no socioeconomic data for med_household_income
# Row 2347 has no socioeconomic data for med_household_income
# Row 2384 has no socioeconomic data for med_household_income
# Row 2546 has no socioeconomic data for med_household_income
# Row 2738 has no socioeconomic data for med_household_income
# Row 2739 has no socioeconomic data for med_household_income
# Row 2745 has no socioeconomic data for med_household_income
# Row 2757 has no socioeconomic data for med_household_income
# Row 2759 has no socioeconomic data for med_household_income
# Row 2854 has no socioeconomic data for med_household_income
# Row 2916 has no socioeconomic data for med_household_income
# Row 2935 has no socioeconomic data for med_household_income
# Row 2943 has no socioeconomic data for med_household_income
# Row 2944 has no socioeconomic data for med_household_income
# Row 2953 has no socioeconomic data for med_household_income
# Row 2958 has no socioeconomic data for med_household_income
# Row 2960 has no socioeconomic data for med_household_income
# Row 2962 has no socioeconomic data for med_household_income
# Row 2966 has no socioeconomic data for med_household_income
# Row 2980 has no socioeconomic data for med_household_income
# Row 2981 has no socioeconomic data for med_household_income
# Row 2994 has no socioeconomic data for med_household_income
# Row 2997 has no socioeconomic data for med_household_income
# Row 3003 has no socioeconomic data for med_household_income
# Row 3004 has no socioeconomic data for med_household_income
# Row 3010 has no socioeconomic data for med_household_income
# Row 3011 has no socioeconomic data for med_household_income
# Row 3013 has no socioeconomic data for med_household_income
# Row 3021 has no socioeconomic data for med_household_income
# Row 3190 has no socioeconomic data for med_household_income
# Row 3215 has no socioeconomic data for med_household_income
# Row 3232 has no socioeconomic data for med_household_income
# Row 3233 has no socioeconomic data for med_household_income
# Row 3237 has no socioeconomic data for med_household_income
# Row 3238 has no socioeconomic data for med_household_income
# Row 3276 has no socioeconomic data for med_household_income
# Row 3277 has no socioeconomic data for med_household_income
# Row 3305 has no socioeconomic data for med_household_income
# Row 3362 has no socioeconomic data for med_household_income
# Row 3363 has no socioeconomic data for med_household_income
# Row 3364 has no socioeconomic data for med_household_income
# Row 3407 has no socioeconomic data for med_household_income
# Row 3459 has no socioeconomic data for med_household_income
# Row 3460 has no socioeconomic data for med_household_income
# Row 3461 has no socioeconomic data for med_household_income
# Row 3471 has no socioeconomic data for med_household_income
# Row 3585 has no socioeconomic data for med_household_income
# Row 3602 has no socioeconomic data for med_household_income
# Row 3802 has no socioeconomic data for med_household_income
# Row 3803 has no socioeconomic data for med_household_income
# Row 3818 has no socioeconomic data for med_household_income
# Row 3824 has no socioeconomic data for med_household_income
# Row 3851 has no socioeconomic data for med_household_income
# Row 3893 has no socioeconomic data for med_household_income
# Row 3922 has no socioeconomic data for med_household_income
# Row 3945 has no socioeconomic data for med_household_income
# Row 3946 has no socioeconomic data for med_household_income
# Row 4017 has no socioeconomic data for med_household_income
# Row 4068 has no socioeconomic data for med_household_income
# Row 4169 has no socioeconomic data for med_household_income
# Row 4237 has no socioeconomic data for med_household_income
# Row 4350 has no socioeconomic data for med_household_income
# Row 4356 has no socioeconomic data for med_household_income
# Row 4397 has no socioeconomic data for med_household_income
# Row 4424 has no socioeconomic data for med_household_income
# Row 4498 has no socioeconomic data for med_household_income
# Row 4656 has no socioeconomic data for med_household_income
# Row 4706 has no socioeconomic data for med_household_income
# Row 4744 has no socioeconomic data for med_household_income
# Row 4745 has no socioeconomic data for med_household_income
# Row 4760 has no socioeconomic data for med_household_income
# Row 4820 has no socioeconomic data for med_household_income
# Row 4878 has no socioeconomic data for med_household_income
# Row 4880 has no socioeconomic data for med_household_income
# Row 4891 has no socioeconomic data for med_household_income
# Row 4986 has no socioeconomic data for med_household_income
# Row 5065 has no socioeconomic data for med_household_income
# Row 5066 has no socioeconomic data for med_household_income
# Row 5097 has no socioeconomic data for med_household_income
# Row 5118 has no socioeconomic data for med_household_income
# Row 5122 has no socioeconomic data for med_household_income
# Row 5128 has no socioeconomic data for med_household_income
# Row 5129 has no socioeconomic data for med_household_income
# Row 5130 has no socioeconomic data for med_household_income
# Row 5248 has no socioeconomic data for med_household_income
# Row 5249 has no socioeconomic data for med_household_income
# Row 5255 has no socioeconomic data for med_household_income
# Row 5256 has no socioeconomic data for med_household_income
# Row 5265 has no socioeconomic data for med_household_income
# Row 5401 has no socioeconomic data for med_household_income
# Row 5612 has no socioeconomic data for med_household_income
# Row 5617 has no socioeconomic data for med_household_income
# Row 5629 has no socioeconomic data for med_household_income
# Row 5795 has no socioeconomic data for med_household_income
# Row 5817 has no socioeconomic data for med_household_income
# Row 6104 has no socioeconomic data for med_household_income
# Row 6108 has no socioeconomic data for med_household_income
# Row 6192 has no socioeconomic data for med_household_income
# Row 6194 has no socioeconomic data for med_household_income
# Row 6214 has no socioeconomic data for med_household_income
# Row 6440 has no socioeconomic data for med_household_income
# Row 6630 has no socioeconomic data for med_household_income
# Row 6721 has no socioeconomic data for med_household_income
# Row 6838 has no socioeconomic data for med_household_income
# Row 6982 has no socioeconomic data for med_household_income
# Row 7075 has no socioeconomic data for med_household_income
# Row 7208 has no socioeconomic data for med_household_income
# Row 7248 has no socioeconomic data for med_household_income
# Row 7320 has no socioeconomic data for med_household_income
# Row 7321 has no socioeconomic data for med_household_income
# Row 7322 has no socioeconomic data for med_household_income
# Row 7323 has no socioeconomic data for med_household_income
# Row 7329 has no socioeconomic data for med_household_income
# Row 7389 has no socioeconomic data for med_household_income
# Row 7467 has no socioeconomic data for med_household_income
# Row 7468 has no socioeconomic data for med_household_income
# Row 7469 has no socioeconomic data for med_household_income
# Row 7530 has no socioeconomic data for med_household_income
# Row 7554 has no socioeconomic data for med_household_income
# Row 7558 has no socioeconomic data for med_household_income
# Row 7559 has no socioeconomic data for med_household_income
# Row 7560 has no socioeconomic data for med_household_income
# Row 7561 has no socioeconomic data for med_household_income
# Row 7562 has no socioeconomic data for med_household_income
# Row 7563 has no socioeconomic data for med_household_income
# Row 7566 has no socioeconomic data for med_household_income
# Row 7567 has no socioeconomic data for med_household_income
# Row 7568 has no socioeconomic data for med_household_income
# Row 7589 has no socioeconomic data for med_household_income
# Row 7590 has no socioeconomic data for med_household_income
# Row 7596 has no socioeconomic data for med_household_income
# Row 7608 has no socioeconomic data for med_household_income
# Row 7643 has no socioeconomic data for med_household_income
# Row 7667 has no socioeconomic data for med_household_income
# Row 7668 has no socioeconomic data for med_household_income
# Row 7680 has no socioeconomic data for med_household_income
# Row 7681 has no socioeconomic data for med_household_income
# Row 7686 has no socioeconomic data for med_household_income
# Row 7695 has no socioeconomic data for med_household_income
# Row 7698 has no socioeconomic data for med_household_income
# Row 7699 has no socioeconomic data for med_household_income
# Row 7708 has no socioeconomic data for med_household_income
# Row 7710 has no socioeconomic data for med_household_income
# Row 7711 has no socioeconomic data for med_household_income
# Row 7716 has no socioeconomic data for med_household_income
# Row 7722 has no socioeconomic data for med_household_income
# Row 7746 has no socioeconomic data for med_household_income
# Row 7747 has no socioeconomic data for med_household_income
# Row 7748 has no socioeconomic data for med_household_income
# Row 7749 has no socioeconomic data for med_household_income
# Row 7750 has no socioeconomic data for med_household_income
# Row 7773 has no socioeconomic data for med_household_income
# Row 7774 has no socioeconomic data for med_household_income
# Row 7785 has no socioeconomic data for med_household_income
# Row 7786 has no socioeconomic data for med_household_income
# Row 7788 has no socioeconomic data for med_household_income
# Row 7797 has no socioeconomic data for med_household_income
# Row 7799 has no socioeconomic data for med_household_income
# Row 7804 has no socioeconomic data for med_household_income
# Row 7807 has no socioeconomic data for med_household_income
# Row 7808 has no socioeconomic data for med_household_income
# Row 7809 has no socioeconomic data for med_household_income
# Row 7810 has no socioeconomic data for med_household_income
# Row 7830 has no socioeconomic data for med_household_income
# Row 7836 has no socioeconomic data for med_household_income
# Row 7874 has no socioeconomic data for med_household_income
# Row 7878 has no socioeconomic data for med_household_income
# Row 7896 has no socioeconomic data for med_household_income
# Row 7897 has no socioeconomic data for med_household_income
# Row 7909 has no socioeconomic data for med_household_income
# Row 7910 has no socioeconomic data for med_household_income
# Row 7911 has no socioeconomic data for med_household_income
# Row 7915 has no socioeconomic data for med_household_income
# Row 7919 has no socioeconomic data for med_household_income
# Row 7934 has no socioeconomic data for med_household_income
# Row 7936 has no socioeconomic data for med_household_income
# Row 7937 has no socioeconomic data for med_household_income
# Row 7938 has no socioeconomic data for med_household_income
# Row 7943 has no socioeconomic data for med_household_income
# Row 7953 has no socioeconomic data for med_household_income
# Row 7954 has no socioeconomic data for med_household_income
# Row 7959 has no socioeconomic data for med_household_income
# Row 7982 has no socioeconomic data for med_household_income
# Row 7983 has no socioeconomic data for med_household_income
# Row 7984 has no socioeconomic data for med_household_income
# Row 7986 has no socioeconomic data for med_household_income
# Row 7998 has no socioeconomic data for med_household_income
# Row 8002 has no socioeconomic data for med_household_income
# Row 8027 has no socioeconomic data for med_household_income
# Row 8055 has no socioeconomic data for med_household_income
# Row 8070 has no socioeconomic data for med_household_income
# Row 8071 has no socioeconomic data for med_household_income
# Row 8076 has no socioeconomic data for med_household_income
# Row 8078 has no socioeconomic data for med_household_income
# Row 8085 has no socioeconomic data for med_household_income
# Row 8093 has no socioeconomic data for med_household_income
# Done: med_household_income
# Row 123 has no socioeconomic data for unemployed
# Row 177 has no socioeconomic data for unemployed
# Row 376 has no socioeconomic data for unemployed
# Row 423 has no socioeconomic data for unemployed
# Row 429 has no socioeconomic data for unemployed
# Row 432 has no socioeconomic data for unemployed
# Row 434 has no socioeconomic data for unemployed
# Row 445 has no socioeconomic data for unemployed
# Row 463 has no socioeconomic data for unemployed
# Row 464 has no socioeconomic data for unemployed
# Row 486 has no socioeconomic data for unemployed
# Row 490 has no socioeconomic data for unemployed
# Row 543 has no socioeconomic data for unemployed
# Row 546 has no socioeconomic data for unemployed
# Row 552 has no socioeconomic data for unemployed
# Row 557 has no socioeconomic data for unemployed
# Row 563 has no socioeconomic data for unemployed
# Row 567 has no socioeconomic data for unemployed
# Row 580 has no socioeconomic data for unemployed
# Row 581 has no socioeconomic data for unemployed
# Row 582 has no socioeconomic data for unemployed
# Row 583 has no socioeconomic data for unemployed
# Row 584 has no socioeconomic data for unemployed
# Row 592 has no socioeconomic data for unemployed
# Row 593 has no socioeconomic data for unemployed
# Row 595 has no socioeconomic data for unemployed
# Row 600 has no socioeconomic data for unemployed
# Row 606 has no socioeconomic data for unemployed
# Row 609 has no socioeconomic data for unemployed
# Row 619 has no socioeconomic data for unemployed
# Row 625 has no socioeconomic data for unemployed
# Row 633 has no socioeconomic data for unemployed
# Row 639 has no socioeconomic data for unemployed
# Row 641 has no socioeconomic data for unemployed
# Row 675 has no socioeconomic data for unemployed
# Row 676 has no socioeconomic data for unemployed
# Row 708 has no socioeconomic data for unemployed
# Row 760 has no socioeconomic data for unemployed
# Row 789 has no socioeconomic data for unemployed
# Row 799 has no socioeconomic data for unemployed
# Row 809 has no socioeconomic data for unemployed
# Row 825 has no socioeconomic data for unemployed
# Row 826 has no socioeconomic data for unemployed
# Row 827 has no socioeconomic data for unemployed
# Row 828 has no socioeconomic data for unemployed
# Row 829 has no socioeconomic data for unemployed
# Row 830 has no socioeconomic data for unemployed
# Row 833 has no socioeconomic data for unemployed
# Row 851 has no socioeconomic data for unemployed
# Row 852 has no socioeconomic data for unemployed
# Row 853 has no socioeconomic data for unemployed
# Row 854 has no socioeconomic data for unemployed
# Row 855 has no socioeconomic data for unemployed
# Row 987 has no socioeconomic data for unemployed
# Row 990 has no socioeconomic data for unemployed
# Row 991 has no socioeconomic data for unemployed
# Row 1031 has no socioeconomic data for unemployed
# Row 1040 has no socioeconomic data for unemployed
# Row 1060 has no socioeconomic data for unemployed
# Row 1098 has no socioeconomic data for unemployed
# Row 1189 has no socioeconomic data for unemployed
# Row 1311 has no socioeconomic data for unemployed
# Row 1459 has no socioeconomic data for unemployed
# Row 1555 has no socioeconomic data for unemployed
# Row 1605 has no socioeconomic data for unemployed
# Row 1620 has no socioeconomic data for unemployed
# Row 1621 has no socioeconomic data for unemployed
# Row 2008 has no socioeconomic data for unemployed
# Row 2051 has no socioeconomic data for unemployed
# Row 2098 has no socioeconomic data for unemployed
# Row 2099 has no socioeconomic data for unemployed
# Row 2100 has no socioeconomic data for unemployed
# Row 2101 has no socioeconomic data for unemployed
# Row 2206 has no socioeconomic data for unemployed
# Row 2234 has no socioeconomic data for unemployed
# Row 2242 has no socioeconomic data for unemployed
# Row 2246 has no socioeconomic data for unemployed
# Row 2247 has no socioeconomic data for unemployed
# Row 2306 has no socioeconomic data for unemployed
# Row 2347 has no socioeconomic data for unemployed
# Row 2384 has no socioeconomic data for unemployed
# Row 2546 has no socioeconomic data for unemployed
# Row 2738 has no socioeconomic data for unemployed
# Row 2739 has no socioeconomic data for unemployed
# Row 2745 has no socioeconomic data for unemployed
# Row 2757 has no socioeconomic data for unemployed
# Row 2759 has no socioeconomic data for unemployed
# Row 2854 has no socioeconomic data for unemployed
# Row 2916 has no socioeconomic data for unemployed
# Row 2935 has no socioeconomic data for unemployed
# Row 2943 has no socioeconomic data for unemployed
# Row 2944 has no socioeconomic data for unemployed
# Row 2953 has no socioeconomic data for unemployed
# Row 2958 has no socioeconomic data for unemployed
# Row 2960 has no socioeconomic data for unemployed
# Row 2962 has no socioeconomic data for unemployed
# Row 2966 has no socioeconomic data for unemployed
# Row 2980 has no socioeconomic data for unemployed
# Row 2981 has no socioeconomic data for unemployed
# Row 2994 has no socioeconomic data for unemployed
# Row 2997 has no socioeconomic data for unemployed
# Row 3003 has no socioeconomic data for unemployed
# Row 3004 has no socioeconomic data for unemployed
# Row 3010 has no socioeconomic data for unemployed
# Row 3011 has no socioeconomic data for unemployed
# Row 3013 has no socioeconomic data for unemployed
# Row 3021 has no socioeconomic data for unemployed
# Row 3190 has no socioeconomic data for unemployed
# Row 3215 has no socioeconomic data for unemployed
# Row 3232 has no socioeconomic data for unemployed
# Row 3233 has no socioeconomic data for unemployed
# Row 3237 has no socioeconomic data for unemployed
# Row 3238 has no socioeconomic data for unemployed
# Row 3276 has no socioeconomic data for unemployed
# Row 3277 has no socioeconomic data for unemployed
# Row 3305 has no socioeconomic data for unemployed
# Row 3362 has no socioeconomic data for unemployed
# Row 3363 has no socioeconomic data for unemployed
# Row 3364 has no socioeconomic data for unemployed
# Row 3407 has no socioeconomic data for unemployed
# Row 3459 has no socioeconomic data for unemployed
# Row 3460 has no socioeconomic data for unemployed
# Row 3461 has no socioeconomic data for unemployed
# Row 3471 has no socioeconomic data for unemployed
# Row 3585 has no socioeconomic data for unemployed
# Row 3602 has no socioeconomic data for unemployed
# Row 3802 has no socioeconomic data for unemployed
# Row 3803 has no socioeconomic data for unemployed
# Row 3818 has no socioeconomic data for unemployed
# Row 3824 has no socioeconomic data for unemployed
# Row 3851 has no socioeconomic data for unemployed
# Row 3893 has no socioeconomic data for unemployed
# Row 3922 has no socioeconomic data for unemployed
# Row 3945 has no socioeconomic data for unemployed
# Row 3946 has no socioeconomic data for unemployed
# Row 4017 has no socioeconomic data for unemployed
# Row 4068 has no socioeconomic data for unemployed
# Row 4169 has no socioeconomic data for unemployed
# Row 4237 has no socioeconomic data for unemployed
# Row 4350 has no socioeconomic data for unemployed
# Row 4356 has no socioeconomic data for unemployed
# Row 4397 has no socioeconomic data for unemployed
# Row 4424 has no socioeconomic data for unemployed
# Row 4498 has no socioeconomic data for unemployed
# Row 4656 has no socioeconomic data for unemployed
# Row 4706 has no socioeconomic data for unemployed
# Row 4744 has no socioeconomic data for unemployed
# Row 4745 has no socioeconomic data for unemployed
# Row 4760 has no socioeconomic data for unemployed
# Row 4820 has no socioeconomic data for unemployed
# Row 4878 has no socioeconomic data for unemployed
# Row 4880 has no socioeconomic data for unemployed
# Row 4891 has no socioeconomic data for unemployed
# Row 4986 has no socioeconomic data for unemployed
# Row 5065 has no socioeconomic data for unemployed
# Row 5066 has no socioeconomic data for unemployed
# Row 5097 has no socioeconomic data for unemployed
# Row 5118 has no socioeconomic data for unemployed
# Row 5122 has no socioeconomic data for unemployed
# Row 5128 has no socioeconomic data for unemployed
# Row 5129 has no socioeconomic data for unemployed
# Row 5130 has no socioeconomic data for unemployed
# Row 5248 has no socioeconomic data for unemployed
# Row 5249 has no socioeconomic data for unemployed
# Row 5255 has no socioeconomic data for unemployed
# Row 5256 has no socioeconomic data for unemployed
# Row 5265 has no socioeconomic data for unemployed
# Row 5401 has no socioeconomic data for unemployed
# Row 5612 has no socioeconomic data for unemployed
# Row 5617 has no socioeconomic data for unemployed
# Row 5629 has no socioeconomic data for unemployed
# Row 5795 has no socioeconomic data for unemployed
# Row 5817 has no socioeconomic data for unemployed
# Row 6104 has no socioeconomic data for unemployed
# Row 6108 has no socioeconomic data for unemployed
# Row 6192 has no socioeconomic data for unemployed
# Row 6194 has no socioeconomic data for unemployed
# Row 6214 has no socioeconomic data for unemployed
# Row 6440 has no socioeconomic data for unemployed
# Row 6630 has no socioeconomic data for unemployed
# Row 6721 has no socioeconomic data for unemployed
# Row 6838 has no socioeconomic data for unemployed
# Row 6982 has no socioeconomic data for unemployed
# Row 7075 has no socioeconomic data for unemployed
# Row 7208 has no socioeconomic data for unemployed
# Row 7248 has no socioeconomic data for unemployed
# Row 7320 has no socioeconomic data for unemployed
# Row 7321 has no socioeconomic data for unemployed
# Row 7322 has no socioeconomic data for unemployed
# Row 7323 has no socioeconomic data for unemployed
# Row 7329 has no socioeconomic data for unemployed
# Row 7389 has no socioeconomic data for unemployed
# Row 7467 has no socioeconomic data for unemployed
# Row 7468 has no socioeconomic data for unemployed
# Row 7469 has no socioeconomic data for unemployed
# Row 7530 has no socioeconomic data for unemployed
# Row 7554 has no socioeconomic data for unemployed
# Row 7558 has no socioeconomic data for unemployed
# Row 7559 has no socioeconomic data for unemployed
# Row 7560 has no socioeconomic data for unemployed
# Row 7561 has no socioeconomic data for unemployed
# Row 7562 has no socioeconomic data for unemployed
# Row 7563 has no socioeconomic data for unemployed
# Row 7566 has no socioeconomic data for unemployed
# Row 7567 has no socioeconomic data for unemployed
# Row 7568 has no socioeconomic data for unemployed
# Row 7589 has no socioeconomic data for unemployed
# Row 7590 has no socioeconomic data for unemployed
# Row 7596 has no socioeconomic data for unemployed
# Row 7608 has no socioeconomic data for unemployed
# Row 7643 has no socioeconomic data for unemployed
# Row 7667 has no socioeconomic data for unemployed
# Row 7668 has no socioeconomic data for unemployed
# Row 7680 has no socioeconomic data for unemployed
# Row 7681 has no socioeconomic data for unemployed
# Row 7686 has no socioeconomic data for unemployed
# Row 7695 has no socioeconomic data for unemployed
# Row 7698 has no socioeconomic data for unemployed
# Row 7699 has no socioeconomic data for unemployed
# Row 7708 has no socioeconomic data for unemployed
# Row 7710 has no socioeconomic data for unemployed
# Row 7711 has no socioeconomic data for unemployed
# Row 7716 has no socioeconomic data for unemployed
# Row 7722 has no socioeconomic data for unemployed
# Row 7746 has no socioeconomic data for unemployed
# Row 7747 has no socioeconomic data for unemployed
# Row 7748 has no socioeconomic data for unemployed
# Row 7749 has no socioeconomic data for unemployed
# Row 7750 has no socioeconomic data for unemployed
# Row 7773 has no socioeconomic data for unemployed
# Row 7774 has no socioeconomic data for unemployed
# Row 7785 has no socioeconomic data for unemployed
# Row 7786 has no socioeconomic data for unemployed
# Row 7788 has no socioeconomic data for unemployed
# Row 7797 has no socioeconomic data for unemployed
# Row 7799 has no socioeconomic data for unemployed
# Row 7804 has no socioeconomic data for unemployed
# Row 7807 has no socioeconomic data for unemployed
# Row 7808 has no socioeconomic data for unemployed
# Row 7809 has no socioeconomic data for unemployed
# Row 7810 has no socioeconomic data for unemployed
# Row 7830 has no socioeconomic data for unemployed
# Row 7836 has no socioeconomic data for unemployed
# Row 7874 has no socioeconomic data for unemployed
# Row 7878 has no socioeconomic data for unemployed
# Row 7896 has no socioeconomic data for unemployed
# Row 7897 has no socioeconomic data for unemployed
# Row 7909 has no socioeconomic data for unemployed
# Row 7910 has no socioeconomic data for unemployed
# Row 7911 has no socioeconomic data for unemployed
# Row 7915 has no socioeconomic data for unemployed
# Row 7919 has no socioeconomic data for unemployed
# Row 7934 has no socioeconomic data for unemployed
# Row 7936 has no socioeconomic data for unemployed
# Row 7937 has no socioeconomic data for unemployed
# Row 7938 has no socioeconomic data for unemployed
# Row 7943 has no socioeconomic data for unemployed
# Row 7953 has no socioeconomic data for unemployed
# Row 7954 has no socioeconomic data for unemployed
# Row 7959 has no socioeconomic data for unemployed
# Row 7982 has no socioeconomic data for unemployed
# Row 7983 has no socioeconomic data for unemployed
# Row 7984 has no socioeconomic data for unemployed
# Row 7986 has no socioeconomic data for unemployed
# Row 7998 has no socioeconomic data for unemployed
# Row 8002 has no socioeconomic data for unemployed
# Row 8027 has no socioeconomic data for unemployed
# Row 8055 has no socioeconomic data for unemployed
# Row 8070 has no socioeconomic data for unemployed
# Row 8071 has no socioeconomic data for unemployed
# Row 8076 has no socioeconomic data for unemployed
# Row 8078 has no socioeconomic data for unemployed
# Row 8085 has no socioeconomic data for unemployed
# Row 8093 has no socioeconomic data for unemployed
# Done: unemployed
# Row 123 has no socioeconomic data for total_pop
# Row 177 has no socioeconomic data for total_pop
# Row 376 has no socioeconomic data for total_pop
# Row 423 has no socioeconomic data for total_pop
# Row 429 has no socioeconomic data for total_pop
# Row 432 has no socioeconomic data for total_pop
# Row 434 has no socioeconomic data for total_pop
# Row 445 has no socioeconomic data for total_pop
# Row 463 has no socioeconomic data for total_pop
# Row 464 has no socioeconomic data for total_pop
# Row 486 has no socioeconomic data for total_pop
# Row 490 has no socioeconomic data for total_pop
# Row 543 has no socioeconomic data for total_pop
# Row 546 has no socioeconomic data for total_pop
# Row 552 has no socioeconomic data for total_pop
# Row 557 has no socioeconomic data for total_pop
# Row 563 has no socioeconomic data for total_pop
# Row 567 has no socioeconomic data for total_pop
# Row 580 has no socioeconomic data for total_pop
# Row 581 has no socioeconomic data for total_pop
# Row 582 has no socioeconomic data for total_pop
# Row 583 has no socioeconomic data for total_pop
# Row 584 has no socioeconomic data for total_pop
# Row 592 has no socioeconomic data for total_pop
# Row 593 has no socioeconomic data for total_pop
# Row 595 has no socioeconomic data for total_pop
# Row 600 has no socioeconomic data for total_pop
# Row 606 has no socioeconomic data for total_pop
# Row 609 has no socioeconomic data for total_pop
# Row 619 has no socioeconomic data for total_pop
# Row 625 has no socioeconomic data for total_pop
# Row 633 has no socioeconomic data for total_pop
# Row 639 has no socioeconomic data for total_pop
# Row 641 has no socioeconomic data for total_pop
# Row 675 has no socioeconomic data for total_pop
# Row 676 has no socioeconomic data for total_pop
# Row 708 has no socioeconomic data for total_pop
# Row 760 has no socioeconomic data for total_pop
# Row 789 has no socioeconomic data for total_pop
# Row 799 has no socioeconomic data for total_pop
# Row 809 has no socioeconomic data for total_pop
# Row 825 has no socioeconomic data for total_pop
# Row 826 has no socioeconomic data for total_pop
# Row 827 has no socioeconomic data for total_pop
# Row 828 has no socioeconomic data for total_pop
# Row 829 has no socioeconomic data for total_pop
# Row 830 has no socioeconomic data for total_pop
# Row 833 has no socioeconomic data for total_pop
# Row 851 has no socioeconomic data for total_pop
# Row 852 has no socioeconomic data for total_pop
# Row 853 has no socioeconomic data for total_pop
# Row 854 has no socioeconomic data for total_pop
# Row 855 has no socioeconomic data for total_pop
# Row 987 has no socioeconomic data for total_pop
# Row 990 has no socioeconomic data for total_pop
# Row 991 has no socioeconomic data for total_pop
# Row 1031 has no socioeconomic data for total_pop
# Row 1040 has no socioeconomic data for total_pop
# Row 1060 has no socioeconomic data for total_pop
# Row 1098 has no socioeconomic data for total_pop
# Row 1189 has no socioeconomic data for total_pop
# Row 1311 has no socioeconomic data for total_pop
# Row 1459 has no socioeconomic data for total_pop
# Row 1555 has no socioeconomic data for total_pop
# Row 1605 has no socioeconomic data for total_pop
# Row 1620 has no socioeconomic data for total_pop
# Row 1621 has no socioeconomic data for total_pop
# Row 2008 has no socioeconomic data for total_pop
# Row 2051 has no socioeconomic data for total_pop
# Row 2098 has no socioeconomic data for total_pop
# Row 2099 has no socioeconomic data for total_pop
# Row 2100 has no socioeconomic data for total_pop
# Row 2101 has no socioeconomic data for total_pop
# Row 2206 has no socioeconomic data for total_pop
# Row 2234 has no socioeconomic data for total_pop
# Row 2242 has no socioeconomic data for total_pop
# Row 2246 has no socioeconomic data for total_pop
# Row 2247 has no socioeconomic data for total_pop
# Row 2306 has no socioeconomic data for total_pop
# Row 2347 has no socioeconomic data for total_pop
# Row 2384 has no socioeconomic data for total_pop
# Row 2546 has no socioeconomic data for total_pop
# Row 2738 has no socioeconomic data for total_pop
# Row 2739 has no socioeconomic data for total_pop
# Row 2745 has no socioeconomic data for total_pop
# Row 2757 has no socioeconomic data for total_pop
# Row 2759 has no socioeconomic data for total_pop
# Row 2854 has no socioeconomic data for total_pop
# Row 2916 has no socioeconomic data for total_pop
# Row 2935 has no socioeconomic data for total_pop
# Row 2943 has no socioeconomic data for total_pop
# Row 2944 has no socioeconomic data for total_pop
# Row 2953 has no socioeconomic data for total_pop
# Row 2958 has no socioeconomic data for total_pop
# Row 2960 has no socioeconomic data for total_pop
# Row 2962 has no socioeconomic data for total_pop
# Row 2966 has no socioeconomic data for total_pop
# Row 2980 has no socioeconomic data for total_pop
# Row 2981 has no socioeconomic data for total_pop
# Row 2994 has no socioeconomic data for total_pop
# Row 2997 has no socioeconomic data for total_pop
# Row 3003 has no socioeconomic data for total_pop
# Row 3004 has no socioeconomic data for total_pop
# Row 3010 has no socioeconomic data for total_pop
# Row 3011 has no socioeconomic data for total_pop
# Row 3013 has no socioeconomic data for total_pop
# Row 3021 has no socioeconomic data for total_pop
# Row 3190 has no socioeconomic data for total_pop
# Row 3215 has no socioeconomic data for total_pop
# Row 3232 has no socioeconomic data for total_pop
# Row 3233 has no socioeconomic data for total_pop
# Row 3237 has no socioeconomic data for total_pop
# Row 3238 has no socioeconomic data for total_pop
# Row 3276 has no socioeconomic data for total_pop
# Row 3277 has no socioeconomic data for total_pop
# Row 3305 has no socioeconomic data for total_pop
# Row 3362 has no socioeconomic data for total_pop
# Row 3363 has no socioeconomic data for total_pop
# Row 3364 has no socioeconomic data for total_pop
# Row 3407 has no socioeconomic data for total_pop
# Row 3459 has no socioeconomic data for total_pop
# Row 3460 has no socioeconomic data for total_pop
# Row 3461 has no socioeconomic data for total_pop
# Row 3471 has no socioeconomic data for total_pop
# Row 3585 has no socioeconomic data for total_pop
# Row 3602 has no socioeconomic data for total_pop
# Row 3802 has no socioeconomic data for total_pop
# Row 3803 has no socioeconomic data for total_pop
# Row 3818 has no socioeconomic data for total_pop
# Row 3824 has no socioeconomic data for total_pop
# Row 3851 has no socioeconomic data for total_pop
# Row 3893 has no socioeconomic data for total_pop
# Row 3922 has no socioeconomic data for total_pop
# Row 3945 has no socioeconomic data for total_pop
# Row 3946 has no socioeconomic data for total_pop
# Row 4017 has no socioeconomic data for total_pop
# Row 4068 has no socioeconomic data for total_pop
# Row 4169 has no socioeconomic data for total_pop
# Row 4237 has no socioeconomic data for total_pop
# Row 4350 has no socioeconomic data for total_pop
# Row 4356 has no socioeconomic data for total_pop
# Row 4397 has no socioeconomic data for total_pop
# Row 4424 has no socioeconomic data for total_pop
# Row 4498 has no socioeconomic data for total_pop
# Row 4656 has no socioeconomic data for total_pop
# Row 4706 has no socioeconomic data for total_pop
# Row 4744 has no socioeconomic data for total_pop
# Row 4745 has no socioeconomic data for total_pop
# Row 4760 has no socioeconomic data for total_pop
# Row 4820 has no socioeconomic data for total_pop
# Row 4878 has no socioeconomic data for total_pop
# Row 4880 has no socioeconomic data for total_pop
# Row 4891 has no socioeconomic data for total_pop
# Row 4986 has no socioeconomic data for total_pop
# Row 5065 has no socioeconomic data for total_pop
# Row 5066 has no socioeconomic data for total_pop
# Row 5097 has no socioeconomic data for total_pop
# Row 5118 has no socioeconomic data for total_pop
# Row 5122 has no socioeconomic data for total_pop
# Row 5128 has no socioeconomic data for total_pop
# Row 5129 has no socioeconomic data for total_pop
# Row 5130 has no socioeconomic data for total_pop
# Row 5248 has no socioeconomic data for total_pop
# Row 5249 has no socioeconomic data for total_pop
# Row 5255 has no socioeconomic data for total_pop
# Row 5256 has no socioeconomic data for total_pop
# Row 5265 has no socioeconomic data for total_pop
# Row 5401 has no socioeconomic data for total_pop
# Row 5612 has no socioeconomic data for total_pop
# Row 5617 has no socioeconomic data for total_pop
# Row 5629 has no socioeconomic data for total_pop
# Row 5795 has no socioeconomic data for total_pop
# Row 5817 has no socioeconomic data for total_pop
# Row 6104 has no socioeconomic data for total_pop
# Row 6108 has no socioeconomic data for total_pop
# Row 6192 has no socioeconomic data for total_pop
# Row 6194 has no socioeconomic data for total_pop
# Row 6214 has no socioeconomic data for total_pop
# Row 6440 has no socioeconomic data for total_pop
# Row 6630 has no socioeconomic data for total_pop
# Row 6721 has no socioeconomic data for total_pop
# Row 6838 has no socioeconomic data for total_pop
# Row 6982 has no socioeconomic data for total_pop
# Row 7075 has no socioeconomic data for total_pop
# Row 7208 has no socioeconomic data for total_pop
# Row 7248 has no socioeconomic data for total_pop
# Row 7320 has no socioeconomic data for total_pop
# Row 7321 has no socioeconomic data for total_pop
# Row 7322 has no socioeconomic data for total_pop
# Row 7323 has no socioeconomic data for total_pop
# Row 7329 has no socioeconomic data for total_pop
# Row 7389 has no socioeconomic data for total_pop
# Row 7467 has no socioeconomic data for total_pop
# Row 7468 has no socioeconomic data for total_pop
# Row 7469 has no socioeconomic data for total_pop
# Row 7530 has no socioeconomic data for total_pop
# Row 7554 has no socioeconomic data for total_pop
# Row 7558 has no socioeconomic data for total_pop
# Row 7559 has no socioeconomic data for total_pop
# Row 7560 has no socioeconomic data for total_pop
# Row 7561 has no socioeconomic data for total_pop
# Row 7562 has no socioeconomic data for total_pop
# Row 7563 has no socioeconomic data for total_pop
# Row 7566 has no socioeconomic data for total_pop
# Row 7567 has no socioeconomic data for total_pop
# Row 7568 has no socioeconomic data for total_pop
# Row 7589 has no socioeconomic data for total_pop
# Row 7590 has no socioeconomic data for total_pop
# Row 7596 has no socioeconomic data for total_pop
# Row 7608 has no socioeconomic data for total_pop
# Row 7643 has no socioeconomic data for total_pop
# Row 7667 has no socioeconomic data for total_pop
# Row 7668 has no socioeconomic data for total_pop
# Row 7680 has no socioeconomic data for total_pop
# Row 7681 has no socioeconomic data for total_pop
# Row 7686 has no socioeconomic data for total_pop
# Row 7695 has no socioeconomic data for total_pop
# Row 7698 has no socioeconomic data for total_pop
# Row 7699 has no socioeconomic data for total_pop
# Row 7708 has no socioeconomic data for total_pop
# Row 7710 has no socioeconomic data for total_pop
# Row 7711 has no socioeconomic data for total_pop
# Row 7716 has no socioeconomic data for total_pop
# Row 7722 has no socioeconomic data for total_pop
# Row 7746 has no socioeconomic data for total_pop
# Row 7747 has no socioeconomic data for total_pop
# Row 7748 has no socioeconomic data for total_pop
# Row 7749 has no socioeconomic data for total_pop
# Row 7750 has no socioeconomic data for total_pop
# Row 7773 has no socioeconomic data for total_pop
# Row 7774 has no socioeconomic data for total_pop
# Row 7785 has no socioeconomic data for total_pop
# Row 7786 has no socioeconomic data for total_pop
# Row 7788 has no socioeconomic data for total_pop
# Row 7797 has no socioeconomic data for total_pop
# Row 7799 has no socioeconomic data for total_pop
# Row 7804 has no socioeconomic data for total_pop
# Row 7807 has no socioeconomic data for total_pop
# Row 7808 has no socioeconomic data for total_pop
# Row 7809 has no socioeconomic data for total_pop
# Row 7810 has no socioeconomic data for total_pop
# Row 7830 has no socioeconomic data for total_pop
# Row 7836 has no socioeconomic data for total_pop
# Row 7874 has no socioeconomic data for total_pop
# Row 7878 has no socioeconomic data for total_pop
# Row 7896 has no socioeconomic data for total_pop
# Row 7897 has no socioeconomic data for total_pop
# Row 7909 has no socioeconomic data for total_pop
# Row 7910 has no socioeconomic data for total_pop
# Row 7911 has no socioeconomic data for total_pop
# Row 7915 has no socioeconomic data for total_pop
# Row 7919 has no socioeconomic data for total_pop
# Row 7934 has no socioeconomic data for total_pop
# Row 7936 has no socioeconomic data for total_pop
# Row 7937 has no socioeconomic data for total_pop
# Row 7938 has no socioeconomic data for total_pop
# Row 7943 has no socioeconomic data for total_pop
# Row 7953 has no socioeconomic data for total_pop
# Row 7954 has no socioeconomic data for total_pop
# Row 7959 has no socioeconomic data for total_pop
# Row 7982 has no socioeconomic data for total_pop
# Row 7983 has no socioeconomic data for total_pop
# Row 7984 has no socioeconomic data for total_pop
# Row 7986 has no socioeconomic data for total_pop
# Row 7998 has no socioeconomic data for total_pop
# Row 8002 has no socioeconomic data for total_pop
# Row 8027 has no socioeconomic data for total_pop
# Row 8055 has no socioeconomic data for total_pop
# Row 8070 has no socioeconomic data for total_pop
# Row 8071 has no socioeconomic data for total_pop
# Row 8076 has no socioeconomic data for total_pop
# Row 8078 has no socioeconomic data for total_pop
# Row 8085 has no socioeconomic data for total_pop
# Row 8093 has no socioeconomic data for total_pop
# Done: total_pop
# Row 123 has no socioeconomic data for gini
# Row 177 has no socioeconomic data for gini
# Row 376 has no socioeconomic data for gini
# Row 423 has no socioeconomic data for gini
# Row 429 has no socioeconomic data for gini
# Row 432 has no socioeconomic data for gini
# Row 434 has no socioeconomic data for gini
# Row 445 has no socioeconomic data for gini
# Row 463 has no socioeconomic data for gini
# Row 464 has no socioeconomic data for gini
# Row 486 has no socioeconomic data for gini
# Row 490 has no socioeconomic data for gini
# Row 543 has no socioeconomic data for gini
# Row 546 has no socioeconomic data for gini
# Row 552 has no socioeconomic data for gini
# Row 557 has no socioeconomic data for gini
# Row 563 has no socioeconomic data for gini
# Row 567 has no socioeconomic data for gini
# Row 580 has no socioeconomic data for gini
# Row 581 has no socioeconomic data for gini
# Row 582 has no socioeconomic data for gini
# Row 583 has no socioeconomic data for gini
# Row 584 has no socioeconomic data for gini
# Row 592 has no socioeconomic data for gini
# Row 593 has no socioeconomic data for gini
# Row 595 has no socioeconomic data for gini
# Row 600 has no socioeconomic data for gini
# Row 606 has no socioeconomic data for gini
# Row 609 has no socioeconomic data for gini
# Row 619 has no socioeconomic data for gini
# Row 625 has no socioeconomic data for gini
# Row 633 has no socioeconomic data for gini
# Row 639 has no socioeconomic data for gini
# Row 641 has no socioeconomic data for gini
# Row 675 has no socioeconomic data for gini
# Row 676 has no socioeconomic data for gini
# Row 708 has no socioeconomic data for gini
# Row 760 has no socioeconomic data for gini
# Row 789 has no socioeconomic data for gini
# Row 799 has no socioeconomic data for gini
# Row 809 has no socioeconomic data for gini
# Row 825 has no socioeconomic data for gini
# Row 826 has no socioeconomic data for gini
# Row 827 has no socioeconomic data for gini
# Row 828 has no socioeconomic data for gini
# Row 829 has no socioeconomic data for gini
# Row 830 has no socioeconomic data for gini
# Row 833 has no socioeconomic data for gini
# Row 851 has no socioeconomic data for gini
# Row 852 has no socioeconomic data for gini
# Row 853 has no socioeconomic data for gini
# Row 854 has no socioeconomic data for gini
# Row 855 has no socioeconomic data for gini
# Row 987 has no socioeconomic data for gini
# Row 990 has no socioeconomic data for gini
# Row 991 has no socioeconomic data for gini
# Row 1031 has no socioeconomic data for gini
# Row 1040 has no socioeconomic data for gini
# Row 1060 has no socioeconomic data for gini
# Row 1098 has no socioeconomic data for gini
# Row 1189 has no socioeconomic data for gini
# Row 1311 has no socioeconomic data for gini
# Row 1459 has no socioeconomic data for gini
# Row 1555 has no socioeconomic data for gini
# Row 1605 has no socioeconomic data for gini
# Row 1620 has no socioeconomic data for gini
# Row 1621 has no socioeconomic data for gini
# Row 2008 has no socioeconomic data for gini
# Row 2051 has no socioeconomic data for gini
# Row 2098 has no socioeconomic data for gini
# Row 2099 has no socioeconomic data for gini
# Row 2100 has no socioeconomic data for gini
# Row 2101 has no socioeconomic data for gini
# Row 2206 has no socioeconomic data for gini
# Row 2234 has no socioeconomic data for gini
# Row 2242 has no socioeconomic data for gini
# Row 2246 has no socioeconomic data for gini
# Row 2247 has no socioeconomic data for gini
# Row 2306 has no socioeconomic data for gini
# Row 2347 has no socioeconomic data for gini
# Row 2384 has no socioeconomic data for gini
# Row 2546 has no socioeconomic data for gini
# Row 2738 has no socioeconomic data for gini
# Row 2739 has no socioeconomic data for gini
# Row 2745 has no socioeconomic data for gini
# Row 2757 has no socioeconomic data for gini
# Row 2759 has no socioeconomic data for gini
# Row 2854 has no socioeconomic data for gini
# Row 2916 has no socioeconomic data for gini
# Row 2935 has no socioeconomic data for gini
# Row 2943 has no socioeconomic data for gini
# Row 2944 has no socioeconomic data for gini
# Row 2953 has no socioeconomic data for gini
# Row 2958 has no socioeconomic data for gini
# Row 2960 has no socioeconomic data for gini
# Row 2962 has no socioeconomic data for gini
# Row 2966 has no socioeconomic data for gini
# Row 2980 has no socioeconomic data for gini
# Row 2981 has no socioeconomic data for gini
# Row 2994 has no socioeconomic data for gini
# Row 2997 has no socioeconomic data for gini
# Row 3003 has no socioeconomic data for gini
# Row 3004 has no socioeconomic data for gini
# Row 3010 has no socioeconomic data for gini
# Row 3011 has no socioeconomic data for gini
# Row 3013 has no socioeconomic data for gini
# Row 3021 has no socioeconomic data for gini
# Row 3190 has no socioeconomic data for gini
# Row 3215 has no socioeconomic data for gini
# Row 3232 has no socioeconomic data for gini
# Row 3233 has no socioeconomic data for gini
# Row 3237 has no socioeconomic data for gini
# Row 3238 has no socioeconomic data for gini
# Row 3276 has no socioeconomic data for gini
# Row 3277 has no socioeconomic data for gini
# Row 3305 has no socioeconomic data for gini
# Row 3362 has no socioeconomic data for gini
# Row 3363 has no socioeconomic data for gini
# Row 3364 has no socioeconomic data for gini
# Row 3407 has no socioeconomic data for gini
# Row 3459 has no socioeconomic data for gini
# Row 3460 has no socioeconomic data for gini
# Row 3461 has no socioeconomic data for gini
# Row 3471 has no socioeconomic data for gini
# Row 3585 has no socioeconomic data for gini
# Row 3602 has no socioeconomic data for gini
# Row 3802 has no socioeconomic data for gini
# Row 3803 has no socioeconomic data for gini
# Row 3818 has no socioeconomic data for gini
# Row 3824 has no socioeconomic data for gini
# Row 3851 has no socioeconomic data for gini
# Row 3893 has no socioeconomic data for gini
# Row 3922 has no socioeconomic data for gini
# Row 3945 has no socioeconomic data for gini
# Row 3946 has no socioeconomic data for gini
# Row 4017 has no socioeconomic data for gini
# Row 4068 has no socioeconomic data for gini
# Row 4169 has no socioeconomic data for gini
# Row 4237 has no socioeconomic data for gini
# Row 4350 has no socioeconomic data for gini
# Row 4356 has no socioeconomic data for gini
# Row 4397 has no socioeconomic data for gini
# Row 4424 has no socioeconomic data for gini
# Row 4498 has no socioeconomic data for gini
# Row 4656 has no socioeconomic data for gini
# Row 4706 has no socioeconomic data for gini
# Row 4744 has no socioeconomic data for gini
# Row 4745 has no socioeconomic data for gini
# Row 4760 has no socioeconomic data for gini
# Row 4820 has no socioeconomic data for gini
# Row 4878 has no socioeconomic data for gini
# Row 4880 has no socioeconomic data for gini
# Row 4891 has no socioeconomic data for gini
# Row 4986 has no socioeconomic data for gini
# Row 5065 has no socioeconomic data for gini
# Row 5066 has no socioeconomic data for gini
# Row 5097 has no socioeconomic data for gini
# Row 5118 has no socioeconomic data for gini
# Row 5122 has no socioeconomic data for gini
# Row 5128 has no socioeconomic data for gini
# Row 5129 has no socioeconomic data for gini
# Row 5130 has no socioeconomic data for gini
# Row 5248 has no socioeconomic data for gini
# Row 5249 has no socioeconomic data for gini
# Row 5255 has no socioeconomic data for gini
# Row 5256 has no socioeconomic data for gini
# Row 5265 has no socioeconomic data for gini
# Row 5401 has no socioeconomic data for gini
# Row 5612 has no socioeconomic data for gini
# Row 5617 has no socioeconomic data for gini
# Row 5629 has no socioeconomic data for gini
# Row 5795 has no socioeconomic data for gini
# Row 5817 has no socioeconomic data for gini
# Row 6104 has no socioeconomic data for gini
# Row 6108 has no socioeconomic data for gini
# Row 6192 has no socioeconomic data for gini
# Row 6194 has no socioeconomic data for gini
# Row 6214 has no socioeconomic data for gini
# Row 6440 has no socioeconomic data for gini
# Row 6630 has no socioeconomic data for gini
# Row 6721 has no socioeconomic data for gini
# Row 6838 has no socioeconomic data for gini
# Row 6982 has no socioeconomic data for gini
# Row 7075 has no socioeconomic data for gini
# Row 7208 has no socioeconomic data for gini
# Row 7248 has no socioeconomic data for gini
# Row 7320 has no socioeconomic data for gini
# Row 7321 has no socioeconomic data for gini
# Row 7322 has no socioeconomic data for gini
# Row 7323 has no socioeconomic data for gini
# Row 7329 has no socioeconomic data for gini
# Row 7389 has no socioeconomic data for gini
# Row 7467 has no socioeconomic data for gini
# Row 7468 has no socioeconomic data for gini
# Row 7469 has no socioeconomic data for gini
# Row 7530 has no socioeconomic data for gini
# Row 7554 has no socioeconomic data for gini
# Row 7558 has no socioeconomic data for gini
# Row 7559 has no socioeconomic data for gini
# Row 7560 has no socioeconomic data for gini
# Row 7561 has no socioeconomic data for gini
# Row 7562 has no socioeconomic data for gini
# Row 7563 has no socioeconomic data for gini
# Row 7566 has no socioeconomic data for gini
# Row 7567 has no socioeconomic data for gini
# Row 7568 has no socioeconomic data for gini
# Row 7589 has no socioeconomic data for gini
# Row 7590 has no socioeconomic data for gini
# Row 7596 has no socioeconomic data for gini
# Row 7608 has no socioeconomic data for gini
# Row 7643 has no socioeconomic data for gini
# Row 7667 has no socioeconomic data for gini
# Row 7668 has no socioeconomic data for gini
# Row 7680 has no socioeconomic data for gini
# Row 7681 has no socioeconomic data for gini
# Row 7686 has no socioeconomic data for gini
# Row 7695 has no socioeconomic data for gini
# Row 7698 has no socioeconomic data for gini
# Row 7699 has no socioeconomic data for gini
# Row 7708 has no socioeconomic data for gini
# Row 7710 has no socioeconomic data for gini
# Row 7711 has no socioeconomic data for gini
# Row 7716 has no socioeconomic data for gini
# Row 7722 has no socioeconomic data for gini
# Row 7746 has no socioeconomic data for gini
# Row 7747 has no socioeconomic data for gini
# Row 7748 has no socioeconomic data for gini
# Row 7749 has no socioeconomic data for gini
# Row 7750 has no socioeconomic data for gini
# Row 7773 has no socioeconomic data for gini
# Row 7774 has no socioeconomic data for gini
# Row 7785 has no socioeconomic data for gini
# Row 7786 has no socioeconomic data for gini
# Row 7788 has no socioeconomic data for gini
# Row 7797 has no socioeconomic data for gini
# Row 7799 has no socioeconomic data for gini
# Row 7804 has no socioeconomic data for gini
# Row 7807 has no socioeconomic data for gini
# Row 7808 has no socioeconomic data for gini
# Row 7809 has no socioeconomic data for gini
# Row 7810 has no socioeconomic data for gini
# Row 7830 has no socioeconomic data for gini
# Row 7836 has no socioeconomic data for gini
# Row 7874 has no socioeconomic data for gini
# Row 7878 has no socioeconomic data for gini
# Row 7896 has no socioeconomic data for gini
# Row 7897 has no socioeconomic data for gini
# Row 7909 has no socioeconomic data for gini
# Row 7910 has no socioeconomic data for gini
# Row 7911 has no socioeconomic data for gini
# Row 7915 has no socioeconomic data for gini
# Row 7919 has no socioeconomic data for gini
# Row 7934 has no socioeconomic data for gini
# Row 7936 has no socioeconomic data for gini
# Row 7937 has no socioeconomic data for gini
# Row 7938 has no socioeconomic data for gini
# Row 7943 has no socioeconomic data for gini
# Row 7953 has no socioeconomic data for gini
# Row 7954 has no socioeconomic data for gini
# Row 7959 has no socioeconomic data for gini
# Row 7982 has no socioeconomic data for gini
# Row 7983 has no socioeconomic data for gini
# Row 7984 has no socioeconomic data for gini
# Row 7986 has no socioeconomic data for gini
# Row 7998 has no socioeconomic data for gini
# Row 8002 has no socioeconomic data for gini
# Row 8027 has no socioeconomic data for gini
# Row 8055 has no socioeconomic data for gini
# Row 8070 has no socioeconomic data for gini
# Row 8071 has no socioeconomic data for gini
# Row 8076 has no socioeconomic data for gini
# Row 8078 has no socioeconomic data for gini
# Row 8085 has no socioeconomic data for gini
# Row 8093 has no socioeconomic data for gini
# Done: gini
# Removing 274 rows with no socioeconomic data

# %%
# save for analysis
subset.to_csv('data/posteda/subset_final.csv', index=False)
